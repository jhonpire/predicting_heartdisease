# %%
from sqlalchemy import create_engine
from config import db_password

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

from matplotlib import ticker
import warnings
warnings.filterwarnings('ignore')
import time
from scipy.stats import norm

# %%
#Loading CSV file "Dataset"
heart_database = pd.read_csv("Resources/heart_2020_cleaned.csv")
heart_database
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
heart_behavioral_data = heart_database.drop(['Sex','AgeCategory','DiffWalking','Race','Diabetic','GenHealth','Asthma','KidneyDisease','SkinCancer'], axis=1)
heart_behavioral_data
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth PhysicalActivity  SleepTime
# ...

# %%
heart_physical_data = heart_database.drop(['BMI','Smoking','AlcoholDrinking','Stroke','PhysicalHealth','MentalHealth','PhysicalActivity','SleepTime'], axis=1)
heart_physical_data
# Out:
#        HeartDisease DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 0                No          No  Female        55-59     White      Yes
# 1                No          No  Female  80 or older     White       No
# 2                No          No    Male        65-69     White      Yes
# 3                No          No  Female        75-79     White       No
# 4                No         Yes  Female        40-44     White       No
# ...             ...         ...     ...          ...       ...      ...
# 319790          Yes         Yes    Male        60-64  Hispanic      Yes
# 319791           No          No    Male        35-39  Hispanic       No
# 319792           No          No  Female        45-49  Hispanic       No
# 319793           No          No  Female        25-29  Hispanic       No
# 319794           No          No  Female  80 or older  Hispanic       No
#
#         GenHealth Asthma KidneyDisease SkinCancer
# 0       Very good    Yes            No        Yes
# ...

# %%
# #Export CSV Files from separate DataFrames "Physical / Behavioral"
# heart_physical_data.to_csv("Resources/heart_phys_data.csv", index=True, header=True)
# heart_behavioral_data.to_csv("Resources/heart_behav_data.csv", index=True, header=True)

# %%
#Connect to Local Database
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Heart_DB"

# %%
#Create ENgine
engine = create_engine(db_string)

# %%
#Create Tables in Postgress SQL
heart_behavioral_data.to_sql(name='Behavioral_Data', con=engine)
heart_physical_data.to_sql(name='Physical_Data', con=engine)
